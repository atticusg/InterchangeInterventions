# %%
import torch
import random
import copy
import itertools
import numpy as np
from sklearn.metrics import classification_report
import utils

from LIM_deep_neural_classifier import LIMDeepNeuralClassifier
import dataset_semantic
from trainer import LIMTrainer

# %%
utils.fix_random_seeds()

# %%
PATH = "basemodel"


X, y = dataset_semantic.generate_data(one_hot=False)

# %%
print(len(X))
# Out:
# 84

# %%
print(len(y))
print(len(y[0]))
# Out:
# 84
# 53

# %%
embedding_dim = 256
VOCAB_SIZE = 25
LIM = LIMDeepNeuralClassifier(
    hidden_dim=512, 
    hidden_activation=torch.nn.ReLU(), 
    #hidden_activation=lambda x: x, 
    num_layers=2,
    input_dim=embedding_dim*2,
    n_classes=53,
   embedding_size_and_dim=(VOCAB_SIZE,embedding_dim)
    )
LIM_trainer = LIMTrainer(
    LIM,
    warm_start=True,
    max_iter=10000,
    batch_size=2,
    l2_strength=0.0,
    n_iter_no_change=10000,
    shuffle_train=True,
    eta=0.0001)

# %%
_ = LIM_trainer.fit(X, y)
# Out:
# Finished epoch 10000 of 10000; error is 115.74587672948837

# %%
preds = LIM_trainer.predict_logits(X).cpu()

# %%
print(preds.shape)
# Out:
# torch.Size([84, 53])

# %%
print(dataset_semantic.classwise_report(y, preds, classes="all"))
# Out:
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# CLASSIFICATION FOR CLASS:pine
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:oak
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:maple
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:birch
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:rose
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:daisy
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:tulip
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:sunflower
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:robin
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:canary
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:sparrow
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:penguin
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:sunfish
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:salmon
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:flounder
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:cod
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:cat
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:dog
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:mouse
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:goat
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:pig
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:plants
#               precision    recall  f1-score   support
#
#          0.0       0.90      1.00      0.95        76
#          1.0       0.00      0.00      0.00         8
#
#     accuracy                           0.90        84
#    macro avg       0.45      0.50      0.48        84
# weighted avg       0.82      0.90      0.86        84
#
#
# CLASSIFICATION FOR CLASS:animals
#               precision    recall  f1-score   support
#
#          0.0       0.85      1.00      0.92        71
#          1.0       0.00      0.00      0.00        13
#
#     accuracy                           0.85        84
#    macro avg       0.42      0.50      0.46        84
# weighted avg       0.71      0.85      0.77        84
#
#
# CLASSIFICATION FOR CLASS:fishes
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:flowers
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:trees
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:birds
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:pretty
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96        78
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.93        84
#    macro avg       0.46      0.50      0.48        84
# weighted avg       0.86      0.93      0.89        84
#
#
# CLASSIFICATION FOR CLASS:big
#               precision    recall  f1-score   support
#
#          0.0       0.90      1.00      0.95        76
#          1.0       0.00      0.00      0.00         8
#
#     accuracy                           0.90        84
#    macro avg       0.45      0.50      0.48        84
# weighted avg       0.82      0.90      0.86        84
#
#
# CLASSIFICATION FOR CLASS:living
#               precision    recall  f1-score   support
#
#          0.0       0.75      1.00      0.86        63
#          1.0       0.00      0.00      0.00        21
#
#     accuracy                           0.75        84
#    macro avg       0.38      0.50      0.43        84
# weighted avg       0.56      0.75      0.64        84
#
#
# CLASSIFICATION FOR CLASS:green
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:red
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        82
#          1.0       0.00      0.00      0.00         2
#
#     accuracy                           0.98        84
#    macro avg       0.49      0.50      0.49        84
# weighted avg       0.95      0.98      0.96        84
#
#
# CLASSIFICATION FOR CLASS:yellow
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:white
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:twirly
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:grow
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87        63
#          1.0       1.00      0.10      0.17        21
#
#     accuracy                           0.77        84
#    macro avg       0.88      0.55      0.52        84
# weighted avg       0.83      0.77      0.70        84
#
#
# CLASSIFICATION FOR CLASS:move
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93        71
#          1.0       1.00      0.15      0.27        13
#
#     accuracy                           0.87        84
#    macro avg       0.93      0.58      0.60        84
# weighted avg       0.89      0.87      0.83        84
#
#
# CLASSIFICATION FOR CLASS:swim
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98        79
#          1.0       1.00      0.40      0.57         5
#
#     accuracy                           0.96        84
#    macro avg       0.98      0.70      0.78        84
# weighted avg       0.97      0.96      0.96        84
#
#
# CLASSIFICATION FOR CLASS:fly
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98        81
#          1.0       0.00      0.00      0.00         3
#
#     accuracy                           0.96        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.93      0.96      0.95        84
#
#
# CLASSIFICATION FOR CLASS:walk
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96        78
#          1.0       0.00      0.00      0.00         6
#
#     accuracy                           0.93        84
#    macro avg       0.46      0.50      0.48        84
# weighted avg       0.86      0.93      0.89        84
#
#
# CLASSIFICATION FOR CLASS:sing
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        83
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.99        84
#    macro avg       0.49      0.50      0.50        84
# weighted avg       0.98      0.99      0.98        84
#
#
# CLASSIFICATION FOR CLASS:leaves
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96        77
#          1.0       0.00      0.00      0.00         7
#
#     accuracy                           0.92        84
#    macro avg       0.46      0.50      0.48        84
# weighted avg       0.84      0.92      0.88        84
#
#
# CLASSIFICATION FOR CLASS:roots
#               precision    recall  f1-score   support
#
#          0.0       0.90      1.00      0.95        76
#          1.0       0.00      0.00      0.00         8
#
#     accuracy                           0.90        84
#    macro avg       0.45      0.50      0.48        84
# weighted avg       0.82      0.90      0.86        84
#
#
# CLASSIFICATION FOR CLASS:skin
#               precision    recall  f1-score   support
#
#          0.0       0.89      1.00      0.94        71
#          1.0       1.00      0.31      0.47        13
#
#     accuracy                           0.89        84
#    macro avg       0.94      0.65      0.71        84
# weighted avg       0.90      0.89      0.87        84
#
#
# CLASSIFICATION FOR CLASS:legs
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97        75
#          1.0       1.00      0.44      0.62         9
#
#     accuracy                           0.94        84
#    macro avg       0.97      0.72      0.79        84
# weighted avg       0.94      0.94      0.93        84
#
#
# CLASSIFICATION FOR CLASS:bark
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:branches
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:petals
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:wings
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        80
#          1.0       1.00      0.50      0.67         4
#
#     accuracy                           0.98        84
#    macro avg       0.99      0.75      0.83        84
# weighted avg       0.98      0.98      0.97        84
#
#
# CLASSIFICATION FOR CLASS:feathers
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        80
#          1.0       1.00      0.50      0.67         4
#
#     accuracy                           0.98        84
#    macro avg       0.99      0.75      0.83        84
# weighted avg       0.98      0.98      0.97        84
#
#
# CLASSIFICATION FOR CLASS:scales
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:gills
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.95        84
#    macro avg       0.48      0.50      0.49        84
# weighted avg       0.91      0.95      0.93        84
#
#
# CLASSIFICATION FOR CLASS:fur
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        80
#          1.0       1.00      0.50      0.67         4
#
#     accuracy                           0.98        84
#    macro avg       0.99      0.75      0.83        84
# weighted avg       0.98      0.98      0.97        84
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
torch.save(LIM_trainer.model.state_dict(), PATH)

# %%
dataset =dataset_semantic.generate_data_plants_have_roots_and_animals_can_move_and_have_skin(one_hot=False)
iit_data = tuple(dataset[2:5])
X_base_train, y_base_train, X_sources_train, y_IIT_train, interventions, blackout_classes = dataset

# %%
print(sum(y[:,22]))
print(sum(y_IIT_train[:,22]))
dataset_semantic.class_to_index("animals")
# Out:
# tensor(13.)
# tensor(1092.)
# 22

# %%
LIM_trainer.model.set_analysis_mode(True)
LIM_trainer.max_iter = 10
LIM_trainer.blackoutclasses = blackout_classes
LIM_trainer.l2_strength = 0.0
LIM_trainer.shuffle_train = False
LIM_trainer.eta = 0.0001

# %%
id_to_coords = {
    0: [{"layer": 1, "start": 0, "end": int(0.25*embedding_dim)}]
}
_ = LIM_trainer.fit(
    X_base_train, 
    y_base_train,    
    iit_data=iit_data,
    intervention_ids_to_coords=id_to_coords)
# Out:
# Finished epoch 10 of 10; error is 102688195.53674316

# %%
base_preds = LIM_trainer.predict_logits(X_base_train.cpu())
print(dataset_semantic.classwise_report(y_base_train.cpu(), base_preds.cpu()))
# Out:
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# CLASSIFICATION FOR CLASS:pine
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:oak
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:maple
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:birch
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:rose
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:daisy
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:tulip
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:sunflower
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:robin
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:canary
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:sparrow
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:penguin
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:sunfish
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:salmon
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:flounder
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:cod
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:cat
# ...
# weighted avg       0.56      0.75      0.64      7056
#
#
# CLASSIFICATION FOR CLASS:move
#               precision    recall  f1-score   support
#
#          0.0       0.85      1.00      0.92      5964
#          1.0       0.00      0.00      0.00      1092
#
#     accuracy                           0.85      7056
#    macro avg       0.42      0.50      0.46      7056
# weighted avg       0.71      0.85      0.77      7056
#
#
# CLASSIFICATION FOR CLASS:swim
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97      6636
#          1.0       0.00      0.00      0.00       420
#
#     accuracy                           0.94      7056
#    macro avg       0.47      0.50      0.48      7056
# weighted avg       0.88      0.94      0.91      7056
#
#
# CLASSIFICATION FOR CLASS:fly
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      6804
#          1.0       0.00      0.00      0.00       252
#
#     accuracy                           0.96      7056
#    macro avg       0.48      0.50      0.49      7056
# weighted avg       0.93      0.96      0.95      7056
#
#
# CLASSIFICATION FOR CLASS:walk
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96      6552
#          1.0       0.00      0.00      0.00       504
#
#     accuracy                           0.93      7056
#    macro avg       0.46      0.50      0.48      7056
# weighted avg       0.86      0.93      0.89      7056
#
#
# CLASSIFICATION FOR CLASS:sing
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6972
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.99      7056
#    macro avg       0.49      0.50      0.50      7056
# weighted avg       0.98      0.99      0.98      7056
#
#
# CLASSIFICATION FOR CLASS:leaves
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96      6468
#          1.0       0.00      0.00      0.00       588
#
#     accuracy                           0.92      7056
#    macro avg       0.46      0.50      0.48      7056
# weighted avg       0.84      0.92      0.88      7056
#
#
# CLASSIFICATION FOR CLASS:roots
#               precision    recall  f1-score   support
#
#          0.0       0.90      1.00      0.95      6384
#          1.0       0.00      0.00      0.00       672
#
#     accuracy                           0.90      7056
#    macro avg       0.45      0.50      0.48      7056
# weighted avg       0.82      0.90      0.86      7056
#
#
# CLASSIFICATION FOR CLASS:skin
#               precision    recall  f1-score   support
#
#          0.0       0.85      1.00      0.92      5964
#          1.0       0.00      0.00      0.00      1092
#
#     accuracy                           0.85      7056
#    macro avg       0.42      0.50      0.46      7056
# weighted avg       0.71      0.85      0.77      7056
#
#
# CLASSIFICATION FOR CLASS:legs
#               precision    recall  f1-score   support
#
#          0.0       0.89      1.00      0.94      6300
#          1.0       0.00      0.00      0.00       756
#
#     accuracy                           0.89      7056
#    macro avg       0.45      0.50      0.47      7056
# weighted avg       0.80      0.89      0.84      7056
#
#
# CLASSIFICATION FOR CLASS:bark
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98      6720
#          1.0       0.00      0.00      0.00       336
#
#     accuracy                           0.95      7056
#    macro avg       0.48      0.50      0.49      7056
# weighted avg       0.91      0.95      0.93      7056
#
#
# CLASSIFICATION FOR CLASS:branches
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98      6720
#          1.0       0.00      0.00      0.00       336
#
#     accuracy                           0.95      7056
#    macro avg       0.48      0.50      0.49      7056
# weighted avg       0.91      0.95      0.93      7056
#
#
# CLASSIFICATION FOR CLASS:petals
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98      6720
#          1.0       0.00      0.00      0.00       336
#
#     accuracy                           0.95      7056
#    macro avg       0.48      0.50      0.49      7056
# weighted avg       0.91      0.95      0.93      7056
#
#
# CLASSIFICATION FOR CLASS:wings
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98      6720
#          1.0       0.00      0.00      0.00       336
#
#     accuracy                           0.95      7056
#    macro avg       0.48      0.50      0.49      7056
# weighted avg       0.91      0.95      0.93      7056
#
#
# CLASSIFICATION FOR CLASS:feathers
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98      6720
#          1.0       0.00      0.00      0.00       336
#
#     accuracy                           0.95      7056
#    macro avg       0.48      0.50      0.49      7056
# weighted avg       0.91      0.95      0.93      7056
#
#
# CLASSIFICATION FOR CLASS:scales
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98      6720
#          1.0       0.00      0.00      0.00       336
#
#     accuracy                           0.95      7056
#    macro avg       0.48      0.50      0.49      7056
# weighted avg       0.91      0.95      0.93      7056
#
#
# CLASSIFICATION FOR CLASS:gills
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98      6720
#          1.0       0.00      0.00      0.00       336
#
#     accuracy                           0.95      7056
#    macro avg       0.48      0.50      0.49      7056
# weighted avg       0.91      0.95      0.93      7056
#
#
# CLASSIFICATION FOR CLASS:fur
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98      6720
#          1.0       0.00      0.00      0.00       336
#
#     accuracy                           0.95      7056
#    macro avg       0.48      0.50      0.49      7056
# weighted avg       0.91      0.95      0.93      7056
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\attic\anaconda3\envs\bigkid\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
IIT_preds = LIM_trainer.iit_predict_logits(X_base_train.cpu(),
                                    [X_sources_train[0].cpu()],
                                    interventions.cpu(),
                                    id_to_coords)
print(dataset_semantic.classwise_report(y_IIT_train.cpu(), IIT_preds.cpu(), classes=["animals","plants","skin","move","roots"]))
# Out:
# CLASSIFICATION FOR CLASS:animals
#               precision    recall  f1-score   support
#
#          0.0       0.86      1.00      0.92      5964
#          1.0       0.98      0.12      0.21      1092
#
#     accuracy                           0.86      7056
#    macro avg       0.92      0.56      0.57      7056
# weighted avg       0.88      0.86      0.81      7056
#
#
# CLASSIFICATION FOR CLASS:plants
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95      6384
#          1.0       0.48      0.03      0.06       672
#
#     accuracy                           0.90      7056
#    macro avg       0.69      0.52      0.51      7056
# weighted avg       0.87      0.90      0.87      7056
#
#
# CLASSIFICATION FOR CLASS:skin
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.99      0.92      5964
#          1.0       0.53      0.07      0.13      1092
#
#     accuracy                           0.85      7056
#    macro avg       0.69      0.53      0.52      7056
# weighted avg       0.80      0.85      0.79      7056
#
#
# CLASSIFICATION FOR CLASS:move
#               precision    recall  f1-score   support
#
#          0.0       0.85      1.00      0.92      5964
#          1.0       0.99      0.07      0.13      1092
#
#     accuracy                           0.86      7056
#    macro avg       0.92      0.53      0.53      7056
# weighted avg       0.87      0.86      0.80      7056
#
#
# CLASSIFICATION FOR CLASS:roots
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95      6384
#          1.0       0.61      0.03      0.06       672
#
#     accuracy                           0.91      7056
#    macro avg       0.76      0.51      0.50      7056
# weighted avg       0.88      0.91      0.87      7056

# %%
for layer in [0,1]:    
    for int_size in [0.5,0.25,0.75, 0.0625, 0.125,]:
        id_to_coords = {
        0: [{"layer": layer, "start": 0, "end": int(int_size*embedding_dim*2)}]
        }
        LIM_trainer.model.load_state_dict(torch.load(PATH))
        _ = LIM_trainer.fit(
        X_base_train, 
        y_base_train,    
        iit_data=iit_data,
        intervention_ids_to_coords=id_to_coords)
        IIT_preds = LIM_trainer.iit_predict_logits(X_base_train.cpu(),
                                    [X_sources_train[0].cpu()],
                                    interventions.cpu(),
                                    id_to_coords)
        print(f"\n\nLayer:{layer} {int_size}")
        print(dataset_semantic.classwise_report(y_IIT_train.cpu(), IIT_preds.cpu(), classes=["animals","plants","skin","move","roots"]))
# Out:
# Finished epoch 8 of 10; error is 385672.86227130896
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20052\4090410817.py in <module>
#       5         }
#       6         LIM_trainer.model.load_state_dict(torch.load(PATH))
# ----> 7         _ = LIM_trainer.fit(
#       8         X_base_train,
#       9         y_base_train,
#
# ~\Documents\GitHub\InterchangeInterventions\trainer.py in fit(self, base, base_labels, iit_data, intervention_ids_to_coords, device)
#     358                     sources_batch, iit_labels_batch, intervention_ids_batch \
#     359                         = self.process_IIT_batch(batch)
# --> 360                     batch_iit_preds = self.model.iit_forward(
#     361                                     base_batch,
#     362                                     sources_batch,
#
# ~\Documents\GitHub\InterchangeInterventions\layered_intervenable_model.py in iit_forward(self, base, sources, intervention_ids, intervention_ids_to_coords)
#     192
#     193         handlers = self._gets_sets(gets = None, sets = sets)
# --> 194         counterfactual_logits = self.forward(base)
#     195         for handler in handlers:
#     196             handler.remove()
#
# ~\Documents\GitHub\InterchangeInterventions\layered_intervenable_model.py in forward(self, X)
#     157         """Computes a forward pass with input `X`."""
#     158         if self.analysis:
# --> 159             return self.analysis_model(X)
#     160         else:
#     161             return self.normal_model(X)
#
# ~\anaconda3\envs\bigkid\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\bigkid\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~\anaconda3\envs\bigkid\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1126             input = bw_hook.setup_input_hook(input)
#    1127
# -> 1128         result = forward_call(*input, **kwargs)
#    1129         if _global_forward_hooks or self._forward_hooks:
#    1130             for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
#
# ~\Documents\GitHub\InterchangeInterventions\layered_intervenable_model.py in forward(self, x)
#      25
#      26     def forward(self, x):
# ---> 27         return torch.matmul(x, self.weight)
#      28
#      29 class LayeredIntervenableModel(torch.nn.Module):
#
# ~\anaconda3\envs\bigkid\lib\site-packages\torch\nn\utils\parametrize.py in get_parametrized(self)
#     340         else:
#     341             # If caching is not active, this function just evaluates the parametrization
# --> 342             return parametrization()
#     343
#     344     def set_original(self, value: Tensor) -> None:
#
# ~\anaconda3\envs\bigkid\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\bigkid\lib\site-packages\torch\nn\utils\parametrize.py in forward(self)
#     258         # Unpack the originals for the first parametrization
#     259         if self.is_tensor:
# --> 260             x = self[0](self.original)
#     261         else:
#     262             originals = (getattr(self, f"original{i}") for i in range(self.ntensors))
#
# ~\anaconda3\envs\bigkid\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\bigkid\lib\site-packages\torch\nn\utils\parametrizations.py in forward(self, X)
#      78                 # Embed into a square matrix
#      79                 X = torch.cat([X, X.new_zeros(n, n - k).expand(*X.shape[:-2], -1, -1)], dim=-1)
# ---> 80             A = X - X.mH
#      81             # A is skew-symmetric (or skew-hermitian)
#      82             if self.orthogonal_map == _OrthMaps.matrix_exp:
#
# KeyboardInterrupt:

# %% [markdown]
# ##
